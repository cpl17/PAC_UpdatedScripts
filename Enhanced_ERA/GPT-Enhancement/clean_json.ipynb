# %%
import pandas as pd
import json

# %%
import json

# Specify the path to your JSON file
json_file_path = 'plants_trimmed.json'

data_dictionary = {}
# Read the JSON file and load it into a dictionary
with open(json_file_path, 'r') as json_file:
    for line in json_file.readlines():
        plant_dictionary = json.loads(line)
        data_dictionary[plant_dictionary["_id"]] = plant_dictionary

# Now, 'data_dictionary' contains the contents of the JSON file as a Python dictionary
print(data_dictionary["Abies amabilis"])
# Out:
# {'_id': 'Abies amabilis', 'USDA Symbol': 'ABAM', 'Local Count': '0', 'Online Counts': '0', 'Local Names': '', 'Blurb': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.', 'Recommendation Score': 1.8, 'QUIZ_FLOWER': '', 'QUIZ_BEE': 'No', 'QUIZ_BUTTERFLY': 'No', 'QUIZ_HUMMINGBIRD': 'No', 'Scientific Name': 'Abies amabilis', 'Common Name': 'Pacific Silver Fir', 'Distribution in USA': 'AK, CA, OR, WA', 'Workhorse': '', 'Showy': False, 'Flowering Months': 'May–Jun', 'Height (feet)': '165', 'Superplant': False, 'metadata': {'extmetadata': {'Artist': {'value': 'No machine-readable author provided. <a href="//commons.wikimedia.org/wiki/User:MPF" title="User:MPF">MPF</a> assumed (based on copyright claims).', 'source': 'commons-desc-page'}, 'LicenseShortName': {'value': 'CC BY 2.5', 'source': 'commons-desc-page',
# ...

# %%
data = pd.read_csv("Blurbs_New.csv")
data = data[:10]
names,blurbs = data["Scientific Name"],data["Blurb"]

for name,blurb in list(zip(names,blurbs)):
    data_dictionary[name]["Blurb"] = blurb

# %%
for key in data_dictionary.keys():
    print(data_dictionary[key]["Blurb"])
# Out:
# Loved for its tall, pyramid-like shape and lush, fragrant needles, this evergreen thrives in cool, moist conditions. In spring, you'll find bees drawn to its cones. While providing nesting for birds, it also serves as a source of timber. Its bark can be used as a natural remedy too.
# Ideal for cold climates, this evergreen conifer thrives in moist, well-drained soil with full sun to partial shade. Attracting pollinators like bees, it features fragrant, resinous bark, needle-like leaves, and purple cones. Valued for timber, pulp, and essential oils, it provides shelter and food for wildlife, including birds and mammals.
# A charming, evergreen tree loved by birds for its seeds. Best comes to life in well-drained, sunny locations. Mostly relies on wind for pollination. Unique tree with stunning cone-bearing branches, providing aesthetic appeal. Survived Ice Age, making it an intriguing conversation starter. Reaches up to 80 feet in height. Known for long lifespan!
# ...

# %%
keys_to_drop = ["_id","Local Count","Online Counts","Workhorse"]

# %%
for name in names:
    for key in keys_to_drop:
        del data_dictionary[name][key]

# %%
keys = [key for key in data_dictionary.keys()]
for key in keys:
    if data_dictionary[key]["metadata"] is None:
        continue
    print(data_dictionary[key]["metadata"])
    data_dictionary["metadata_extmetadata_Artist_value"] = data_dictionary[key]["metadata"]["extmetadata"]["Artist"]["value"]
    data_dictionary["metadata_extmetadata_Artist_source"] = data_dictionary[key]["metadata"]["extmetadata"]["Artist"]["source"]
    data_dictionary["metadata_extmetadata_LicenseShortName_source"] = data_dictionary[key]["metadata"]["extmetadata"]["LicenseShortName"]["source"]
    data_dictionary["metadata_extmetadata_LicenseShortName_value"] = data_dictionary[key]["metadata"]["extmetadata"]["LicenseShortName"]["value"]
# Out:
# {'extmetadata': {'Artist': {'value': 'No machine-readable author provided. <a href="//commons.wikimedia.org/wiki/User:MPF" title="User:MPF">MPF</a> assumed (based on copyright claims).', 'source': 'commons-desc-page'}, 'LicenseShortName': {'value': 'CC BY 2.5', 'source': 'commons-desc-page', 'hidden': ''}, 'LicenseUrl': {'value': 'https://creativecommons.org/licenses/by/2.5', 'source': 'commons-desc-page'}}}
# {'extmetadata': {'Artist': {'value': 'U.S. Fish and Wildlife Service', 'source': 'commons-desc-page'}, 'LicenseShortName': {'value': 'Public domain', 'source': 'commons-desc-page', 'hidden': ''}}}
# ...

# %%
keys
# Out:
# ['Abies amabilis',
#  'Abies balsamea',
#  'Abies bracteata',
#  'Abies concolor',
#  'Abies fraseri',
#  'Abies grandis',
#  'Abies lasiocarpa',
#  'Abies magnifica',
#  'Abies procera',
#  'Abronia ammophila',
#  'Abronia fragrans',
#  'Abronia latifolia',
#  'Abronia maritima',
#  'Abronia mellifera',
#  'Abronia umbellata',
#  'Abronia villosa',
#  'Abutilon eremitopetalum',
#  'Abutilon incanum',
#  'Abutilon malacum',
#  'Abutilon menziesii',
#  'Abutilon permolle',
#  'Abutilon wrightii',
#  'Acacia angustissima',
#  'Acacia constricta',
#  'Acacia farnesiana',
#  'Acacia greggii',
#  'Acacia koa',
#  'Acacia koaia',
#  'Acacia rigidula',
#  'Acalypha rhomboidea',
#  'Acalypha virginica',
#  'Acamptopappus shockleyi',
#  'Acamptopappus sphaerocephalus',
#  'Acer circinatum',
#  'Acer floridanum',
#  'Acer glabrum',
#  'Acer grandidentatum',
#  'Acer macrophyllum',
#  'Acer negundo',
#  'Acer nigrum',
#  'Acer pensylvanicum',
#  'Acer rubrum',
#  'Acer saccharinum',
# ...

# %%
keys_to_drop = ["_id","Local Count","Online Counts","Workhorse","metadata"]
